# %% [markdown]
# # User-Defined Data Structure
#
# ## 1.Stack
# > Stack is a linear collection of items that supports LIFO (last-in, first-out) semantics for insertion and deletion.
# > For instance: stack of plates at restaurant are added or removed from the top (last) , not from the bottom (first).

# %% [markdown]
# ### 1.1 There are two types of operations in Stack:
# 1. Push: to add data into
# 2. Pop: to remove data from

# %% [markdown]
# ## 1.1.1. PUSH
# > Push: adds element at the top of the stack  ![push.png](attachment:push.png)

# %% [markdown]
# ## 1.1.2. POP
# > Pop: removes element from the top of the stack  ![pop.png](attachment:pop.png)

# %% [markdown]
# ## 1.2 How to implement Stack in Python?
# > In Python, Stacks can be implement by:
# 1. list: using built-in list data structure.
# 2. collections.deque: using deque library.
# 3. queue.LifoQueue: using queue.LifoQueue class.
# __We will only focus on using list to create Stack__

# %% [markdown]
# ## 1.3 Create Stack with List
# > Use append() function to push.
# > Use pop() function to pop in LIFO order.

# %%
#Create empty stack (list) & add 3 elements into the list
stack = []
stack.append('Below')
stack.append('Middle')
stack.append('Top')
print('After append: ', stack)
# Out:
# After append:  ['Below', 'Middle', 'Top']

# %%
# pop or remove element from stack
print('Popping out once: ', stack.pop())
# Out:
# Popping out once:  Top

# %%
# pop or remove element from stack
print('Popping out again: ', stack.pop())
# Out:
# Popping out again:  Middle

# %%
# checking the left over 
print('Check for the last element in the stack: ', stack)
# Out:
# Check for the last element in the stack:  ['Below']

# %% [markdown]
# ## 2.Queue
# > Queue is the opposite of Stack, it is based on FIFO (First-in, First-out). <br>     ![queue.png](attachment:queue.png)

# %% [markdown]
# ## 2.2 How to implement Queue in Python?
# > In Python, Stacks can be implement by:
# 1. list: using built-in list data structure.
# 2. collections.deque: using deque library.
# 3. queue.Queue: using queue.Queue class.  <br><br>
# __We will NOT be talking about QUEUE here.__  <br>
# __To learn more about "Queue":__  https://www.geeksforgeeks.org/queue-in-python/

# %% [markdown]
# ***
# *Lang Tuang: SEP 4th,2021*
# ***
